# %%
x = input("Please enter your first name:")
y = input("Please enter your last name:")
z = x + ' ' + y
print("Here is your name:",z,"\n")
print("Your Name has length :",len(x+y),"\n")
print("The string with your name has length:",len(z),"\n")
l1 = ['a','e','i','o','u']
print(l1,"\n")
k = (len(z) % 5)
print ("Your name string has length:",k," Modulo 5","\n")
print ("Your Name length modulo 5, maps to the following vocal:",l1[k],"\n")
if l1[k] in z : print(l1[k],'∈','z','=',True)

for el in l1 : 
    if el in z : print(el,'∈','z','=',True)
    if el not in z : print(el,'∈','z','=',False)

print ("\n","Thanks a lot for using this program, have a nice day!")
